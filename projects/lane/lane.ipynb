# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import opencv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-143bf375b57f> in <module>()
#       2 import matplotlib.image as mpimg
#       3 import numpy as np
# ----> 4 import opencv
#
# ModuleNotFoundError: No module named 'opencv'

# %%
# reading in an image

image = mpimg.imread('lane.png')

# printing out some stats and plotting the image

print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)
plt.show()
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (571, 1000, 4)

# %%
height=571
width=1000
region_of_interest_vertices = [
    (0, height),
    (width / 2, height / 2),
    (width, height),
]

def region_of_interest(img, vertices):
    # Define a blank matrix that matches the image height/width.
    mask = np.zeros_like(img)

    # Retrieve the number of color channels of the image.
    channel_count = img.shape[2]

    # Create a match color with the same color channel counts.
    match_mask_color = (255,) * channel_count
      
    # Fill inside the polygon
    cv2.fillPoly(mask, vertices, match_mask_color)
    
    # Returning the image only where mask pixels match
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

cropped_image = region_of_interest(
    image,
    np.array([region_of_interest_vertices], np.int32),
)

plt.figure()
plt.imshow(cropped_image)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4c1a8601a1a0> in <module>()
#      26 cropped_image = region_of_interest(
#      27     image,
# ---> 28     np.array([region_of_interest_vertices], np.int32),
#      29 )
#      30
#
# <ipython-input-8-4c1a8601a1a0> in region_of_interest(img, vertices)
#      18
#      19     # Fill inside the polygon
# ---> 20     cv2.fillPoly(mask, vertices, match_mask_color)
#      21
#      22     # Returning the image only where mask pixels match
#
# NameError: name 'cv2' is not defined
